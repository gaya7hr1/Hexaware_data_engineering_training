# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SparkSQL Lab").getOrCreate()


employees_data = [
    (1, "Rahul", "IT", 70000, "Hyderabad"),
    (2, "Sneha", "HR", 60000, "Bangalore"),
    (3, "Arjun", "IT", 75000, "Chennai"),
    (4, "Priya", "Finance", 80000, "Hyderabad"),
    (5, "Karan", "IT", 50000, "Mumbai"),
    (6, "Amit", "HR", 58000, "Delhi"),
    (7, "Meera", "Finance", 82000, "Bangalore")
]

employees_cols = ["emp_id", "name", "department", "salary", "city"]

employees_df = spark.createDataFrame(employees_data, employees_cols)
employees_df.show()

departments_data = [
    ("IT", "Technology"),
    ("HR", "People Operations"),
    ("Finance", "Accounts and Finance")
]

departments_cols = ["department", "dept_full_name"]

departments_df = spark.createDataFrame(departments_data, departments_cols)
departments_df.show()

sales_data = [
    (101, 1, "Laptop", 1, 75000),
    (102, 2, "Mouse", 3, 500),
    (103, 3, "Keyboard", 2, 1500),
    (104, 1, "Monitor", 1, 12000),
    (105, 4, "Laptop", 1, 75000),
    (106, 3, "Mouse", 2, 500),
    (107, 5, "Keyboard", 1, 1500),
    (108, 1, "Laptop", 1, 75000)
]

sales_cols = ["sale_id", "emp_id", "product", "quantity", "price"]

sales_df = spark.createDataFrame(sales_data, sales_cols)
sales_df.show()
# Out:
# +------+-----+----------+------+---------+
# |emp_id| name|department|salary|     city|
# +------+-----+----------+------+---------+
# |     1|Rahul|        IT| 70000|Hyderabad|
# |     2|Sneha|        HR| 60000|Bangalore|
# |     3|Arjun|        IT| 75000|  Chennai|
# |     4|Priya|   Finance| 80000|Hyderabad|
# |     5|Karan|        IT| 50000|   Mumbai|
# |     6| Amit|        HR| 58000|    Delhi|
# |     7|Meera|   Finance| 82000|Bangalore|
# +------+-----+----------+------+---------+
#
# +----------+--------------------+
# |department|      dept_full_name|
# +----------+--------------------+
# |        IT|          Technology|
# |        HR|   People Operations|
# |   Finance|Accounts and Finance|
# +----------+--------------------+
#
# +-------+------+--------+--------+-----+
# |sale_id|emp_id| product|quantity|price|
# +-------+------+--------+--------+-----+
# |    101|     1|  Laptop|       1|75000|
# |    102|     2|   Mouse|       3|  500|
# |    103|     3|Keyboard|       2| 1500|
# |    104|     1| Monitor|       1|12000|
# |    105|     4|  Laptop|       1|75000|
# |    106|     3|   Mouse|       2|  500|
# |    107|     5|Keyboard|       1| 1500|
# |    108|     1|  Laptop|       1|75000|
# +-------+------+--------+--------+-----+

# %% [markdown]
# # local temp view

# %%
employees_df.createOrReplaceTempView("employees")
departments_df.createOrReplaceTempView("departments")
sales_df.createOrReplaceTempView("sales")

# %%
spark.sql("SELECT * FROM employees").show()
# Out:
# +------+-----+----------+------+---------+
# |emp_id| name|department|salary|     city|
# +------+-----+----------+------+---------+
# |     1|Rahul|        IT| 70000|Hyderabad|
# |     2|Sneha|        HR| 60000|Bangalore|
# |     3|Arjun|        IT| 75000|  Chennai|
# |     4|Priya|   Finance| 80000|Hyderabad|
# |     5|Karan|        IT| 50000|   Mumbai|
# |     6| Amit|        HR| 58000|    Delhi|
# |     7|Meera|   Finance| 82000|Bangalore|
# +------+-----+----------+------+---------+

# %% [markdown]
# # global view temp

# %%
employees_df.createOrReplaceGlobalTempView("g_employees")

# %%
spark.sql("SELECT * FROM global_temp.g_employees").show()
# Out:
# +------+-----+----------+------+---------+
# |emp_id| name|department|salary|     city|
# +------+-----+----------+------+---------+
# |     1|Rahul|        IT| 70000|Hyderabad|
# |     2|Sneha|        HR| 60000|Bangalore|
# |     3|Arjun|        IT| 75000|  Chennai|
# |     4|Priya|   Finance| 80000|Hyderabad|
# |     5|Karan|        IT| 50000|   Mumbai|
# |     6| Amit|        HR| 58000|    Delhi|
# |     7|Meera|   Finance| 82000|Bangalore|
# +------+-----+----------+------+---------+

# %%
spark.sql("create database if not exists company_db")
# Out:
# DataFrame[]

# %%
spark.sql("show databases").show()
# Out:
# +----------+
# | namespace|
# +----------+
# |company_db|
# |   default|
# +----------+

# %%
spark.sql("use company_db")
# Out:
# DataFrame[]

# %%
spark.sql("select current_database()").show()
# Out:
# +----------------+
# |current_schema()|
# +----------------+
# |      company_db|
# +----------------+

# %%
# Create table
spark.sql("""
CREATE TABLE IF NOT EXISTS employee_master (
    emp_id INT,
    name STRING,
    department STRING,
    salary INT,
    city STRING
)
USING PARQUET
""")

# Insert data
spark.sql("""
INSERT INTO employee_master VALUES
(1, 'Rahul', 'IT', 70000, 'Hyderabad'),
(2, 'Sneha', 'HR', 60000, 'Bangalore'),
(3, 'Arjun', 'IT', 75000, 'Chennai'),
(4, 'Priya', 'Finance', 80000, 'Hyderabad')
""")

# Display data
spark.sql("SELECT * FROM employee_master").show()
# Out:
# +------+-----+----------+------+---------+
# |emp_id| name|department|salary|     city|
# +------+-----+----------+------+---------+
# |     3|Arjun|        IT| 75000|  Chennai|
# |     4|Priya|   Finance| 80000|Hyderabad|
# |     1|Rahul|        IT| 70000|Hyderabad|
# |     2|Sneha|        HR| 60000|Bangalore|
# +------+-----+----------+------+---------+

# %% [markdown]
# create a table from a dataframe

# %%
employees_df.write.mode("overwrite").saveAsTable("employee_details")

# %%
spark.sql("select * from employee_details").show()
# Out:
# +------+-----+----------+------+---------+
# |emp_id| name|department|salary|     city|
# +------+-----+----------+------+---------+
# |     4|Priya|   Finance| 80000|Hyderabad|
# |     5|Karan|        IT| 50000|   Mumbai|
# |     6| Amit|        HR| 58000|    Delhi|
# |     7|Meera|   Finance| 82000|Bangalore|
# |     1|Rahul|        IT| 70000|Hyderabad|
# |     2|Sneha|        HR| 60000|Bangalore|
# |     3|Arjun|        IT| 75000|  Chennai|
# +------+-----+----------+------+---------+

# %%
spark.sql("show tables in company_db").show()
# Out:
# +----------+----------------+-----------+
# | namespace|       tableName|isTemporary|
# +----------+----------------+-----------+
# |company_db|employee_details|      false|
# |company_db| employee_master|      false|
# |          |     departments|       true|
# |          |       employees|       true|
# |          |           sales|       true|
# +----------+----------------+-----------+

# %%
spark.sql("create or replace view high_salary_employees as select emp_id,name,department, salary from employee_details where salary>70000")
# Out:
# DataFrame[]

# %%
spark.sql("select * from high_salary_employees").show()
# Out:
# +------+-----+----------+------+
# |emp_id| name|department|salary|
# +------+-----+----------+------+
# |     4|Priya|   Finance| 80000|
# |     7|Meera|   Finance| 82000|
# |     3|Arjun|        IT| 75000|
# +------+-----+----------+------+

# %%
spark.sql("""create or replace view employee_in_south as select emp_id ,department,city from employee_details where city = 'Hyderabad'or city ='Bangalore'"""
)
#or
'''
spark.sql("""create or replace view employee_in_south as select emp_id ,department,city from employee_details where city in ('Hyderabad','Bangalore')""")
'''
# Out:
# DataFrame[]

# %%
spark.sql("select * from employee_in_south").show()
# Out:
# +------+----------+---------+
# |emp_id|department|     city|
# +------+----------+---------+
# |     4|   Finance|Hyderabad|
# |     7|   Finance|Bangalore|
# |     1|        IT|Hyderabad|
# |     2|        HR|Bangalore|
# +------+----------+---------+

# %%
spark.sql("select * from employee_details where department='IT'").show()
# Out:
# +------+-----+----------+------+---------+
# |emp_id| name|department|salary|     city|
# +------+-----+----------+------+---------+
# |     5|Karan|        IT| 50000|   Mumbai|
# |     1|Rahul|        IT| 70000|Hyderabad|
# |     3|Arjun|        IT| 75000|  Chennai|
# +------+-----+----------+------+---------+

# %% [markdown]
# # Joins

# %%
spark.sql("""
select e.emp_id,e.name,e.department,e.salary,e.city,d.dept_full_name
from employee_details e
inner join departments d on e.department=d.department
"""
).show()
# Out:
# +------+-----+----------+------+---------+--------------------+
# |emp_id| name|department|salary|     city|      dept_full_name|
# +------+-----+----------+------+---------+--------------------+
# |     3|Arjun|        IT| 75000|  Chennai|          Technology|
# |     1|Rahul|        IT| 70000|Hyderabad|          Technology|
# |     5|Karan|        IT| 50000|   Mumbai|          Technology|
# |     2|Sneha|        HR| 60000|Bangalore|   People Operations|
# |     6| Amit|        HR| 58000|    Delhi|   People Operations|
# |     7|Meera|   Finance| 82000|Bangalore|Accounts and Finance|
# |     4|Priya|   Finance| 80000|Hyderabad|Accounts and Finance|
# +------+-----+----------+------+---------+--------------------+

# %%
spark.sql("""
select e.emp_id,e.name,e.department,e.salary,e.city,d.dept_full_name
from employee_details e
left join departments d on e.department=d.department
""").show()
# Out:
# +------+-----+----------+------+---------+--------------------+
# |emp_id| name|department|salary|     city|      dept_full_name|
# +------+-----+----------+------+---------+--------------------+
# |     6| Amit|        HR| 58000|    Delhi|   People Operations|
# |     4|Priya|   Finance| 80000|Hyderabad|Accounts and Finance|
# |     7|Meera|   Finance| 82000|Bangalore|Accounts and Finance|
# |     5|Karan|        IT| 50000|   Mumbai|          Technology|
# |     2|Sneha|        HR| 60000|Bangalore|   People Operations|
# |     1|Rahul|        IT| 70000|Hyderabad|          Technology|
# |     3|Arjun|        IT| 75000|  Chennai|          Technology|
# +------+-----+----------+------+---------+--------------------+

# %%
spark.sql("""
select e.emp_id,e.name,e.department,e.salary,e.city,d.dept_full_name
from employee_details e
right join departments d on e.department=d.department
""").show()
# Out:
# +------+-----+----------+------+---------+--------------------+
# |emp_id| name|department|salary|     city|      dept_full_name|
# +------+-----+----------+------+---------+--------------------+
# |     3|Arjun|        IT| 75000|  Chennai|          Technology|
# |     1|Rahul|        IT| 70000|Hyderabad|          Technology|
# |     5|Karan|        IT| 50000|   Mumbai|          Technology|
# |     2|Sneha|        HR| 60000|Bangalore|   People Operations|
# |     6| Amit|        HR| 58000|    Delhi|   People Operations|
# |     7|Meera|   Finance| 82000|Bangalore|Accounts and Finance|
# |     4|Priya|   Finance| 80000|Hyderabad|Accounts and Finance|
# +------+-----+----------+------+---------+--------------------+

# %%
spark.sql("""
select department , count(*) as emp_count
from employees
group by department""").show()
# Out:
# +----------+---------+
# |department|emp_count|
# +----------+---------+
# |        HR|        2|
# |        IT|        3|
# |   Finance|        2|
# +----------+---------+

# %%
spark.sql("""
select department, avg(salary) as avg_salary
from employee_details
group by department
""").show()
# Out:
# +----------+----------+
# |department|avg_salary|
# +----------+----------+
# |        HR|   59000.0|
# |   Finance|   81000.0|
# |        IT|   65000.0|
# +----------+----------+

# %%
spark.sql("""
select e.name,sum(s.quantity*s.price) as total_sales
from employees e
join sales s
on e.emp_id=s.emp_id
group by e.name""").show()
# Out:
# +-----+-----------+
# | name|total_sales|
# +-----+-----------+
# |Sneha|       1500|
# |Priya|      75000|
# |Rahul|     162000|
# |Arjun|       4000|
# |Karan|       1500|
# +-----+-----------+

# %% [markdown]
# # Group by, Having Clause

# %%
spark.sql("""
select department, avg(salary) as avg_salary
from employee_details
group by department
having avg(salary)>65000""").show()
# Out:
# +----------+----------+
# |department|avg_salary|
# +----------+----------+
# |   Finance|   81000.0|
# +----------+----------+

# %%
spark.sql("""
select product, sum(quantity) as total_quantity
from sales
group by product
having sum(quantity)>2
""").show()
# Out:
# +--------+--------------+
# | product|total_quantity|
# +--------+--------------+
# |  Laptop|             3|
# |   Mouse|             5|
# |Keyboard|             3|
# +--------+--------------+

# %% [markdown]
# # Order by

# %%
spark.sql(
    """
    select * from employee_details
    order by salary desc
"""
).show()
# Out:
# +------+-----+----------+------+---------+
# |emp_id| name|department|salary|     city|
# +------+-----+----------+------+---------+
# |     7|Meera|   Finance| 82000|Bangalore|
# |     4|Priya|   Finance| 80000|Hyderabad|
# |     3|Arjun|        IT| 75000|  Chennai|
# |     1|Rahul|        IT| 70000|Hyderabad|
# |     2|Sneha|        HR| 60000|Bangalore|
# |     6| Amit|        HR| 58000|    Delhi|
# |     5|Karan|        IT| 50000|   Mumbai|
# +------+-----+----------+------+---------+

# %%
spark.sql(
    """
    select product, sum(quantity * price) as total_revenue
    from sales
    group by product
    order by total_revenue desc
"""
).show()
# Out:
# +--------+-------------+
# | product|total_revenue|
# +--------+-------------+
# |  Laptop|       225000|
# | Monitor|        12000|
# |Keyboard|         4500|
# |   Mouse|         2500|
# +--------+-------------+

# %% [markdown]
# # Dense rank

# %%
spark.sql("""
select emp_id,
name,department,salary,
dense_rank() over (partition by department order by salary desc) as salary_rank
from employees
""").show()
# Out:
# +------+-----+----------+------+-----------+
# |emp_id| name|department|salary|salary_rank|
# +------+-----+----------+------+-----------+
# |     7|Meera|   Finance| 82000|          1|
# |     4|Priya|   Finance| 80000|          2|
# |     2|Sneha|        HR| 60000|          1|
# |     6| Amit|        HR| 58000|          2|
# |     3|Arjun|        IT| 75000|          1|
# |     1|Rahul|        IT| 70000|          2|
# |     5|Karan|        IT| 50000|          3|
# +------+-----+----------+------+-----------+
